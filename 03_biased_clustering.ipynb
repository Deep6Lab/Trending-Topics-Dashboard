# %% [markdown]
# # Biased Clustering
#
# This notebook uses time-biased clustering to detect trends in financial journals.

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from Biased_Clusters import get_clusters_dist, get_clusters_timeline, get_top_keywords, get_silhouette, cal_cluster_bias

# %%
# load cleaned data
df = pd.read_csv('data/data_cleaned.csv')
df.head()
# Out:
#    Year  Year_Scaled    Year_STD  Month  \
# 0  2020     1.309502  172.088518  March
# 1  2020     1.309502  172.088518  March
# 2  2020     1.309502  172.088518  March
# 3  2020     1.309502  172.088518  March
# 4  2020     1.309502  172.088518  March
#
#                                             Keywords  \
# 0  ['Capital structure', 'Corporate taxation', 'D...
# 1  ['Credit spreads', 'LBO risk', 'Structural mod...
# 2  ['Fire sales', 'Liquidity management', 'Mutual...
# 3  ['Asset pricing', 'Leverage constraints', 'Lot...
# 4  ['Gender gap', 'Entrepreneurship', 'Angel inve...
#
#                                             Abstract  \
# 0  Absent theoretical guidance, empiricists have ...
# 1  Recent decades have witnessed several waves of...
# 2  We develop three novel measures of the incenti...
# 3  We test whether the low-risk effect is driven ...
# 4  We study whether early stage investors have ge...
#
#                                     Abstract_Cleaned  Abstract Length  \
# 0  absent theoret guidance empiricist forc reli u...             1047
# 1  recent decad wit sever wave buyout activity fi...              580
# 2  develop three novel measur incent equiti mutua...              586
# 3  test whether lowrisk effect driven leverag con...              861
# 4  studi whether earli stage investor gender bias...              742
#
#                                     Keywords_Cleaned  Number of Keywords  \
# 0  ['capital structure', 'corporate taxation', 'd...                   5
# 1  ['credit spreads', 'lbo risk', 'structural mod...                   4
# 2  ['fire sales', 'liquidity management', 'mutual...                   3
# 3  ['asset pricing', 'leverage constraints', 'lot...                   5
# 4  ['gender gap', 'entrepreneurship', 'angel inve...                   4
#
#    Month_Cleaned
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3

# %% [markdown]
# ## Biased Clustering

# %%
# build trend score table

# load training data
x_vector = np.load('data/x_vector.npy')

# steps = [i for i in range(1,1000, 50)]
data = []

# get Silhouette score, std year for various bias amount
for m in tqdm(range(1,1000,10)):
    m = m*.01

    try:
        data.append(get_silhouette(df, x_vector, m))
    except ValueError:
        continue

# create a dataframe to store the results
df_result = pd.DataFrame(data)

# save df_result to csv file
df_result.to_csv('data/table_trend_score.csv', index=False)

# display the first 5 rows of df_result
df_result.head()
# Out:
# 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
#    step  Silhouette Score  silhouette_clsuter_1  std_year_cluster_1  \
# 0  0.01          0.401087              0.138561            0.890458
# 1  0.11          0.392377              0.417502            1.011822
# 2  0.21          0.394902              0.305599            0.711571
# 3  0.31          0.394768              0.507219            0.969751
# 4  0.41          0.391660              0.517036            0.879088
#
#    silhouette_by_std_year_cluster_1  silhouette_clsuter_2  std_year_cluster_2  \
# 0                          0.155606              0.091259            1.033853
# 1                          0.412624              0.102580            0.912889
# 2                          0.429471              0.141670            0.857936
# 3                          0.523040              0.118583            0.903324
# 4                          0.588150              0.105480            0.917896
#
#    silhouette_by_std_year_cluster_2  silhouette_clsuter_3  std_year_cluster_3  \
# 0                          0.088270              0.471724            0.777657
# 1                          0.112369              0.464789            1.226889
# 2                          0.165129              0.072841            1.081688
# 3                          0.131274              0.545162            0.961835
# 4                          0.114915              0.405788            1.181116
#
#    ...  silhouette_clsuter_14  std_year_cluster_14  \
# 0  ...               0.548945             0.965180
# 1  ...               0.106491             0.883233
# 2  ...               0.129190             0.885802
# 3  ...               0.501449             0.693164
# 4  ...               0.374557             0.858492
#
#    silhouette_by_std_year_cluster_14  silhouette_clsuter_15  \
# 0                           0.568749               0.148511
# 1                           0.120570               0.415601
# 2                           0.145845               0.160048
# 3                           0.723421               0.397489
# 4                           0.436296               0.498144
#
#    std_year_cluster_15  silhouette_by_std_year_cluster_15  std_tfidf  \
# 0             0.891817                           0.166527   1.398914
# 1             1.177908                           0.352830   1.381413
# 2             0.954357                           0.167702   1.389396
# 3             0.959855                           0.414114   1.389313
# 4             0.693164                           0.718652   1.383925
#
#     avg_std  avg_std_year  avg_silhouette_by_std_year
# 0  0.162029      0.949418                    0.408044
# 1  0.163185      0.938209                    0.410346
# 2  0.162186      0.949212                    0.402559
# 3  0.155819      0.956667                    0.410818
# 4  0.173859      0.948760                    0.404727
#
# [5 rows x 51 columns]

# %%
import json
import scipy.sparse

# load terms sparse matrix
terms_sparse_matrix = scipy.sparse.load_npz('data/terms_sparse_matrix.npz')

# load terms label
with open("data/terms_label.txt", "r") as fp:
    terms_label = json.load(fp)

# make predictions
summary, predictions = cal_cluster_bias(df, x_vector, terms_sparse_matrix, terms_label, 0.57)

# %%
summary
# Out:
#                                                 Terms  Trend Score  \
# 0   effect, find, returns, estim, term, structur, ...     0.475847
# 1   ep, dates, noinform, clientel, aggreg, larg, a...     0.493886
# 2   returns, interv, increas, find, asset, aggreg,...     0.908194
# 3   order, relat, use, control, ownership, tax, st...     0.141796
# 4   team, signals, interquartil, label, japanes, c...     1.037225
# 5   use, effect, activ, trade, market, posit, earn...     0.368486
# 6   acquisit, announc, return, firms, invest, incr...     0.616076
# 7   perform, models, data, factor, empir, portfoli...     0.377243
# 8   condit, paper, invest, predict, find, explain,...     0.377685
# 9   investor, use, portfolio, forward, call, valua...     0.367841
# 10  flow, result, relat, high, earn, cash, abnorm,...     0.460320
# 11  order, impact, examin, use, abnorm, trader, ea...     0.438259
# 12  increas, pay, effect, stock, manageri, ownersh...     0.514576
# 13  corpor, credit, inform, firms, effect, model, ...     0.590000
# 14  stock, underwrit, equiti, public, effect, issu...     0.430849
#
#     Bias Avg Std Year  Silhoutte Score  Number of Articles  \
# 0            0.944438         0.449408                 263
# 1            1.001476         0.494615                  14
# 2            0.646902         0.587512                  10
# 3            0.885826         0.125607                 403
# 4            0.855856         0.887715                  10
# 5            0.871256         0.321045                 276
# 6            0.908284         0.559572                 131
# 7            1.182285         0.446009                 171
# 8            1.017945         0.384462                 257
# 9            1.230563         0.452651                 217
# 10           0.965141         0.444274                 128
# 11           1.040645         0.456072                 164
# 12           0.809944         0.416778                 263
# 13           0.785064         0.463188                 255
# 14           0.858482         0.369876                 296
#
#     Percentage of Articles  Cluster Id  \
# 0                 0.092022           1
# 1                 0.004899           2
# 2                 0.003499           3
# 3                 0.141008           4
# 4                 0.003499           5
# 5                 0.096571           6
# 6                 0.045836           7
# 7                 0.059832           8
# 8                 0.089923           9
# 9                 0.075927          10
# 10                0.044787          11
# 11                0.057383          12
# 12                0.092022          13
# 13                0.089223          14
# 14                0.103569          15
#
#                                              Timeline
# 0          1974-1978, 1980-1982, 1984-1992, 1995-2020
# 1        1986-1988, 1994, 2001, 2006, 2012, 2014-2016
# 2        1989, 2006, 2008, 2010-2011, 2014-2015, 2017
# 3                     1974-1977, 1979-1980, 1983-2020
# 4              1983, 1994-1998, 2001-2002, 2015, 2020
# 5         1975, 1977-1978, 1980, 1983-1993, 1995-2020
# 6   1975, 1978, 1983, 1985-1987, 1989-1992, 1994-2020
# 7                                           1974-2020
# 8                                1974-1994, 1996-2020
# 9                                1974-1987, 1989-2020
# 10                         1977, 1981-1993, 1995-2020
# 11        1974, 1976-1977, 1979, 1981-1984, 1986-2020
# 12  1974, 1976, 1980, 1983-1987, 1989-1992, 1994-2020
# 13              1977, 1983-1985, 1989-1996, 1998-2020
# 14                         1977-1978, 1980, 1983-2020

# %%
predictions.head()
# Out:
#    Year  Year_Scaled    Year_STD  Month  \
# 0  2020     1.309502  172.088518  March
# 1  2020     1.309502  172.088518  March
# 2  2020     1.309502  172.088518  March
# 3  2020     1.309502  172.088518  March
# 4  2020     1.309502  172.088518  March
#
#                                             Keywords  \
# 0  ['Capital structure', 'Corporate taxation', 'D...
# 1  ['Credit spreads', 'LBO risk', 'Structural mod...
# 2  ['Fire sales', 'Liquidity management', 'Mutual...
# 3  ['Asset pricing', 'Leverage constraints', 'Lot...
# 4  ['Gender gap', 'Entrepreneurship', 'Angel inve...
#
#                                             Abstract  \
# 0  Absent theoretical guidance, empiricists have ...
# 1  Recent decades have witnessed several waves of...
# 2  We develop three novel measures of the incenti...
# 3  We test whether the low-risk effect is driven ...
# 4  We study whether early stage investors have ge...
#
#                                     Abstract_Cleaned  Abstract Length  \
# 0  absent theoret guidance empiricist forc reli u...             1047
# 1  recent decad wit sever wave buyout activity fi...              580
# 2  develop three novel measur incent equiti mutua...              586
# 3  test whether lowrisk effect driven leverag con...              861
# 4  studi whether earli stage investor gender bias...              742
#
#                                     Keywords_Cleaned  Number of Keywords  \
# 0  ['capital structure', 'corporate taxation', 'd...                   5
# 1  ['credit spreads', 'lbo risk', 'structural mod...                   4
# 2  ['fire sales', 'liquidity management', 'mutual...                   3
# 3  ['asset pricing', 'leverage constraints', 'lot...                   5
# 4  ['gender gap', 'entrepreneurship', 'angel inve...                   4
#
#    Month_Cleaned  Cluster Id
# 0              3          10
# 1              3          14
# 2              3           6
# 3              3           9
# 4              3           4

# %%
get_clusters_dist(predictions).head()
# Out:
#    Year  Cluster Id  Number of Articles
# 0  1974           1                   2
# 1  1974           4                   1
# 2  1974           8                   1
# 3  1974           9                   4
# 4  1974          10                   4

# %%
# save prediction
summary.to_csv('data/summary_bias_0.57.csv', index=False)
predictions.to_csv('data/predictions_0.57.csv', index=False)
